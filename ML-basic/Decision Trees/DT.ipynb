# %%
from IPython.display import Image
Image("data/1.png")

# %%
Image("data/2.png")

# %% [markdown]
# gini vs Entropy
# https://sebastianraschka.com/faq/docs/decision-tree-binary.html

# %% [markdown]
# Гиперпараметры
#
#     1) Максимальная глубина
#     2) минимальное количество делений
#     3) Минимальное количество образцов на лист
#     4) Минимальное количество выборок на сплит

# %%
# Регрессия
Image("data/3.png")
