# %%
from IPython.display import Image
Image("data/1.png")

# %%
Image("data/2.png")

# %% [markdown]
# Если SVM переобучается, можно попробовать регуляризовать путем сокращения C

# %%
Image("data/3.png")

# %%
Image("data/4.png")

# %% [markdown]
# # Регрессия

# %%
Image("data/5.png")
