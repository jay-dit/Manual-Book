# %%
from IPython.display import Image
Image("data/1.png")

# %%
# k-means
Image("data/2.png")

# %%
Image("data/3.png")

# %%
Image("data/4.png")

# %%
Image("data/5.png")

# %% [markdown]
# Чтобы узнать оптимальное количество кластеров можно начертить график инерции или silhoute_score

# %%
Image("data/6.png")

# %%
Image("data/7.png")

# %%
Image("data/8.png")

# %%
# Смеси Гаусовских распределений
Image("data/9.png")

# %%
Image("data/10.png")

# %%
Image("data/11.png")
